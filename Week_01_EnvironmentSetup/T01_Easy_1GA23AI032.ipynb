# %%
# !pip install qiskit qiskit-aer
# Out:
# Collecting qiskit
#   Downloading qiskit-2.5.1-cp310-abi3-win_amd64.whl.metadata (14 kB)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy<3,>=2.0 in c:\users\niyathi\anaconda\lib\site-packages (from qiskit) (2.3.5)
# Requirement already satisfied: scipy>=1.14 in c:\users\niyathi\anaconda\lib\site-packages (from qiskit) (1.16.3)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.18.0-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in c:\users\niyathi\anaconda\lib\site-packages (from qiskit) (0.4.0)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in c:\users\niyathi\anaconda\lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in c:\users\niyathi\anaconda\lib\site-packages (from qiskit-aer) (7.0.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\niyathi\anaconda\lib\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\niyathi\anaconda\lib\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Downloading qiskit-2.5.1-cp310-abi3-win_amd64.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ----------------------- ---------------- 5.5/9.4 MB 30.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 26.5 MB/s  0:00:00
# Downloading qiskit_aer-0.17.2-cp313-cp313-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    -------------------------- ------------- 6.3/9.6 MB 29.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 25.8 MB/s  0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 31.5 MB/s  0:00:00
# Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
# Installing collected packages: stevedore, rustworkx, qiskit, qiskit-aer
#
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------- ----------------------------- 1/4 [rustworkx]
#    ---------- ----------------------------- 1/4 [rustworkx]
#    ---------- ----------------------------- 1/4 [rustworkx]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    -------------------- ------------------- 2/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ------------------------------ --------- 3/4 [qiskit-aer]
#    ---------------------------------------- 4/4 [qiskit-aer]
#
# Successfully installed qiskit-2.5.1 qiskit-aer-0.17.2 rustworkx-0.18.0 stevedore-5.9.0

# %%
import qiskit

print("Qiskit Version:", qiskit.__version__)
# Out:
# Qiskit Version: 2.5.1

# %%
from qiskit_aer import Aer

print("Available Backends:")

for backend in Aer.backends():
    print("-", backend.name)
# Out:
# Available Backends:
# - aer_simulator
# - aer_simulator_statevector
# - aer_simulator_density_matrix
# - aer_simulator_stabilizer
# - aer_simulator_matrix_product_state
# - aer_simulator_extended_stabilizer
# - aer_simulator_unitary
# - aer_simulator_superop
# - qasm_simulator
# - statevector_simulator
# - unitary_simulator
