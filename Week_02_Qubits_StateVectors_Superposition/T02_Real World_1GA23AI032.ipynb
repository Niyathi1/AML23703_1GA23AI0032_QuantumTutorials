# %%
# !pip install qiskit qiskit-aer matplotlib
# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit in c:\users\student\appdata\roaming\python\python311\site-packages (1.3.0)
# Requirement already satisfied: qiskit-aer in c:\users\student\appdata\roaming\python\python311\site-packages (0.15.1)
# Requirement already satisfied: matplotlib in c:\users\student\appdata\roaming\python\python311\site-packages (3.10.8)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\student\appdata\roaming\python\python311\site-packages (from qiskit) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\programdata\anaconda3\lib\site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\student\appdata\roaming\python\python311\site-packages (from qiskit) (1.17.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\student\appdata\roaming\python\python311\site-packages (from qiskit) (1.13.1)
# Requirement already satisfied: dill>=0.3 in c:\users\student\appdata\roaming\python\python311\site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\programdata\anaconda3\lib\site-packages (from qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\student\appdata\roaming\python\python311\site-packages (from qiskit) (5.4.0)
# Requirement already satisfied: typing-extensions in c:\users\student\appdata\roaming\python\python311\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\student\appdata\roaming\python\python311\site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: psutil>=5 in c:\programdata\anaconda3\lib\site-packages (from qiskit-aer) (5.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\student\appdata\roaming\python\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\student\appdata\roaming\python\python311\site-packages (from stevedore>=3.0.0->qiskit) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.3->qiskit) (1.3.0)
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_state_qsphere
import matplotlib.pyplot as plt

# %%
theta=0.2
qc=QuantumCircuit(1)
qc.h(0)
qc.p(theta,0)
sv=Statevector.from_instruction(qc)
display(plot_bloch_multivector(sv))
