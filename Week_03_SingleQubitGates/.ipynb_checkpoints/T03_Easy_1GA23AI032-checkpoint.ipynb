# %%
import qiskit
import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector, Operator
from qiskit.visualization import plot_histogram, plot_bloch_multivector

print("Qiskit Version:", qiskit.__version__)
simulator = AerSimulator()
print(simulator)
# Out:
# Qiskit Version: 2.5.1
# AerSimulator('aer_simulator')

# %%
gates = {
    "Pauli-X": lambda qc: qc.x(0),
    "Pauli-Y": lambda qc: qc.y(0),
    "Pauli-Z": lambda qc: qc.z(0)
}

for name, apply_gate in gates.items():
    qc = QuantumCircuit(1)
    apply_gate(qc)
    state = Statevector.from_instruction(qc)
    print(f"\n{name} circuit:")
    print(qc)
    print("Resulting statevector:", state)
# Out:
# Pauli-X circuit:
#    ┌───┐
# q: ┤ X ├
#    └───┘
# Resulting statevector: Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
#
# Pauli-Y circuit:
#    ┌───┐
# q: ┤ Y ├
#    └───┘
# Resulting statevector: Statevector([0.+0.j, 0.+1.j],
#             dims=(2,))
#
# Pauli-Z circuit:
#    ┌───┐
# q: ┤ Z ├
#    └───┘
# Resulting statevector: Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
