# %%
# Import Required Libraries
import qiskit
import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector, Operator
from qiskit.visualization import plot_histogram, plot_bloch_multivector

print("Qiskit Version:", qiskit.__version__)
simulator = AerSimulator()
print(simulator)
# Out:
# Qiskit Version: 2.5.1
# AerSimulator('aer_simulator')

# %%
# Analytical proof: HZH = X
import random

I = np.eye(2, dtype=complex)
X = np.array([[0, 1], [1, 0]], dtype=complex)
Y = np.array([[0, -1j], [1j, 0]], dtype=complex)
Z = np.array([[1, 0], [0, -1]], dtype=complex)
H = (1 / np.sqrt(2)) * np.array([[1, 1], [1, -1]], dtype=complex)
S = np.array([[1, 0], [0, 1j]], dtype=complex)
T = np.array([[1, 0], [0, np.exp(1j*np.pi/4)]], dtype=complex)

HZH = H @ Z @ H

print("H Z H =")
print(np.round(HZH, 6))

print("\nX =")
print(X)

print("\nAnalytically, HZH is equivalent to X:",
      np.allclose(HZH, X))

# Circuit verification
qc_hzh = QuantumCircuit(1)
qc_hzh.h(0)
qc_hzh.z(0)
qc_hzh.h(0)

qc_x = QuantumCircuit(1)
qc_x.x(0)

state_hzh = Statevector.from_instruction(qc_hzh)
state_x = Statevector.from_instruction(qc_x)

print("\nState after HZH:", state_hzh)
print("State after X:", state_x)

print("\nCircuit simulation verifies equivalence:",
      np.allclose(state_hzh.data, state_x.data))
# Out:
# H Z H =
# [[-0.+0.j  1.+0.j]
#  [ 1.+0.j -0.+0.j]]
#
# X =
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]
#
# Analytically, HZH is equivalent to X: True
#
# State after HZH: Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# State after X: Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
#
# Circuit simulation verifies equivalence: True
